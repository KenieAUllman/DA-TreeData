# %%
from ipywidgets import interact

# %%
def ident(val):
    return val

# %%
interact(ident, val=(0, 100, 100))
# Out:
# interactive(children=(IntSlider(value=0, description='val', step=100), Output()), _dom_classes=('widget-intera…
# <function __main__.ident(val)>

# %%
def add(a,b):
    return a + b

# %%
interact(add, a=10, b=20)
# Out:
# interactive(children=(IntSlider(value=10, description='a', max=30, min=-10), IntSlider(value=20, description='…
# <function __main__.add(a, b)>

# %%
def indent2(val):
    return val

# %%
interact(indent2, val="Hello")
# Out:
# interactive(children=(Text(value='Hello', description='val'), Output()), _dom_classes=('widget-interact',))
# <function __main__.indent2(val)>

# %%
def my_len(s):
    return len(s)

# %%
interact(my_len, s="hello")
# Out:
# interactive(children=(Text(value='hello', description='s'), Output()), _dom_classes=('widget-interact',))
# <function __main__.my_len(s)>

# %%
interact(ident, val=True)
# Out:
# interactive(children=(Checkbox(value=True, description='val'), Output()), _dom_classes=('widget-interact',))
# <function __main__.ident(val)>

# %%
interact(ident, val= {"small", "medium", "large"})
# Out:
# interactive(children=(Dropdown(description='val', options=('medium', 'large', 'small'), value='medium'), Outpu…
# <function __main__.ident(val)>

# %%
interact(ident, val={"small": 0, "medium": 1, "large": 2})
# Out:
# interactive(children=(Dropdown(description='val', options={'small': 0, 'medium': 1, 'large': 2}, value=0), Out…
# <function __main__.ident(val)>

# %%
import ipywidgets as widgets

# %%
interact(ident, val=widgets.IntRangeSlider(min=-50, max=50, value=[-10, 20]))
# Out:
# interactive(children=(IntRangeSlider(value=(-10, 20), description='val', max=50, min=-50), Output()), _dom_cla…
# <function __main__.ident(val)>

# %%
interact(ident, val=widgets.ColorPicker(value="green"))
# Out:
# interactive(children=(ColorPicker(value='green', description='val'), Output()), _dom_classes=('widget-interact…
# <function __main__.ident(val)>

# %%
pip install ipyleaflet
# Out:
# Collecting ipyleaflet
#   Using cached ipyleaflet-0.15.0-py2.py3-none-any.whl (3.3 MB)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipyleaflet) (7.6.5)
# Collecting traittypes<3,>=0.2.1
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Collecting xyzservices>=2021.8.1
#   Using cached xyzservices-2022.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ullma\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (6.4.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ullma\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (5.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (5.1.3)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (7.29.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (3.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ullma\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (6.1.12)
# Requirement already satisfied: decorator in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (5.1.0)
# Requirement already satisfied: colorama in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (58.0.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: backcall in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.18.0)
# Requirement already satisfied: pygments in c:\users\ullma\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (2.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ullma\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ullma\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ullma\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\ullma\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ullma\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ullma\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ullma\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ullma\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\ullma\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\ullma\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ullma\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (6.4.5)
# Requirement already satisfied: argon2-cffi in c:\users\ullma\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (20.1.0)
# Requirement already satisfied: jinja2 in c:\users\ullma\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (2.11.3)
# Requirement already satisfied: nbconvert in c:\users\ullma\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ullma\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\ullma\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\ullma\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.11.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\ullma\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\ullma\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\ullma\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ullma\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.3)
# Requirement already satisfied: bleach in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.5.3)
# Requirement already satisfied: testpath in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\ullma\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.7.1)
# Requirement already satisfied: nest-asyncio in c:\users\ullma\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\ullma\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.10)
# Requirement already satisfied: webencodings in c:\users\ullma\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.5.1)
# Requirement already satisfied: packaging in c:\users\ullma\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\ullma\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.0.4)
# Installing collected packages: xyzservices, traittypes, ipyleaflet
# Successfully installed ipyleaflet-0.15.0 traittypes-0.2.1 xyzservices-2022.2.0

# %%
from ipyleaflet import Map

# %%
m = Map(center=[36.1744, -86.7679], zoom= 10)

# %%
print(m)
# Out:
# Map(center=[36.1744, -86.7679], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.Mapnik', options=['attribution', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms'], url='https://a.tile.openstreetmap.org/{z}/{x}/{y}.png'),), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap', 'zoom_start'], style=MapStyle(), zoom=10.0)

# %%
m
# Out:
# Map(center=[36.1744, -86.7679], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
import ipywidgets as widgets

# %%
city = widgets.Dropdown(options= ["Chattanooga", "Knoxville", "Memphis", "Nashville"], value="Nashville")

# %%
pip install IPython.display
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement IPython.display (from versions: none)
# ERROR: No matching distribution found for IPython.display

# %%
from IPython.display import display

# %%
display(city)
# Out:
# Dropdown(index=3, options=('Chattanooga', 'Knoxville', 'Memphis', 'Nashville'), value='Nashville')

# %%
city.value = "Knoxville"

# %%
btn = widgets.Button(description="Take Action")
display(btn)
# Out:
# Button(description='Take Action', style=ButtonStyle())
# 05:53:52 PM

# %%
import datetime
def btn_clicked(b):
    print(datetime.datetime.now().strftime("%I:%M:%S %p"))

# %%
btn.on_click(btn_clicked)

# %%
display(city)
# Out:
# Dropdown(index=1, options=('Chattanooga', 'Knoxville', 'Memphis', 'Nashville'), value='Knoxville')

# %%
def city_observer(bunch): 
    print(bunch)

# %%
city.observe(city_observer, names="values")
